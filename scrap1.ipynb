# %%
import requests 
from bs4 import BeautifulSoup as BS
import csv 
  
URL = "https://www.udemy.com/the-web-developer-bootcamp/"
# r = requests.get(URL) 
agent = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
page = requests.get(URL, headers=agent)
print (BS(page.content, 'lxml'))  
# soup = BS(page.content, 'html-parser') 

  
# quotes=[]  # a list to store quotes 
  
# table = soup.find('div', attrs = {'id':'container'}) 
  
# for row in table.findAll('div', attrs = {'class':'quote'}): 
#     quote = {} 
#     quote['theme'] = row.h5.text 
#     quote['url'] = row.a['href'] 
#     quote['img'] = row.img['src'] 
#     quote['lines'] = row.h6.text 
#     quote['author'] = row.p.text 
#     quotes.append(quote) 
  
# filename = 'inspirational_quotes.csv'
# with open(filename, 'wb') as f: 
#     w = csv.DictWriter(f,['theme','url','img','lines','author']) 
#     w.writeheader() 
#     for quote in quotes: 
#         w.writerow(quote) 
# table = soup.find('div', attrs = {'class':'main-content-wrapper.main-content'})
print(soup.prettify())

# print(table.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us">
# <head>
# <title>The Web Developer Bootcamp | Udemy</title>
# <meta content="The only course you need to learn web development - HTML, CSS, JS, Node, and More!" name="description"/><meta content="The Web Developer Bootcamp" name="title"/><meta content="summary_large_image" name="twitter:card"/><meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/><meta content="mult" name="medium"/><meta content="app-id=562413829, affiliate-data=ct=Safari_SmartBanner&amp;amp;pt=1240482" name="apple-itunes-app"/><meta content="app-id=com.udemy.android" name="google-play-app"/><meta content="313137469260" property="fb:app_id"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><meta content="1" property="udemy_com:available"/><meta content="Development" property="udemy_com:category"/><meta content="https://www.udemy.com/user/coltsteele/" property="udemy_com:instructor"/><meta content="₹12,800" property="udemy_com:price"/><meta content="The Web Developer Bootcamp" property="og:title"/><meta content="https://www.udemy.com/the-web-developer-bootcamp/" property="og:url"/><meta content="The only course you need to learn web development - HTML, CSS, JS, Node, and More!" property="og:description"/><meta content="https://i.udemycdn.com/course/480x270/625204_436a_2.jpg" property="og:image"/><meta content="udemy_com:course" property="og:type"/><meta content="Udemy" property="og:site_name"/><meta content="en_US" property="og:locale"/><meta content="www.udemy.com" name="twitter:domain"/><meta content="The Web Developer Bootcamp" name="twitter:title"/><meta content="https://www.udemy.com/the-web-developer-bootcamp/" name="twitter:url"/><meta content="The only course you need to learn web development - HTML, CSS, JS, Node, and More!" name="twitter:description"/><meta content="https://i.udemycdn.com/course/480x270/625204_436a_2.jpg" name="twitter:image"/><meta content="@udemy" name="twitter:site"/><meta content="The Web Developer Bootcamp" itemprop="name"/><meta content="https://www.udemy.com/the-web-developer-bootcamp/" itemprop="url"/><meta content="The only course you need to learn web development - HTML, CSS, JS, Node, and More!" itemprop="description"/><meta content="https://i.udemycdn.com/course/480x270/625204_436a_2.jpg" itemprop="image"/>
# <link href="/staticx/udemy/js/webpack/entry-main-legacy.307ddb08351ca7f30602.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="" href="https://udemy-images.udemy.com" rel="preconnect"/>
# <link crossorigin="" href="https://udemy-images.udemy.com" rel="dns-prefetch"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://www.udemy.com/staticx/udemy/images/v6/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
# <meta content="Udemy" name="application-name"/>
# <meta content="#EDECE6" name="msapplication-TileColor"/>
# <meta content="https://www.udemy.com/staticx/udemy/images/v6/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="https://www.udemy.com/staticx/udemy/images/v6/mstile-70x70.png" name="msapplication-square70x70logo"/>
# <meta content="https://www.udemy.com/staticx/udemy/images/v6/mstile-150x150.png" name="msapplication-square150x150logo"/>
# <meta content="https://www.udemy.com/staticx/udemy/images/v6/mstile-310x150.png" name="msapplication-wide310x150logo"/>
# <meta content="https://www.udemy.com/staticx/udemy/images/v6/mstile-310x310.png" name="msapplication-square310x310logo"/>
# <style>/* cyrillic-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OX-hpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OVuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 300;
#     src: local('Open Sans Light'), local('OpenSans-Light'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUuhpKKSTjw.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OXOhv.woff) format('woff');
#     unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFWJ0bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFUZ0bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFWZ0bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVp0bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFWp0bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50bf8pkAp6a.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 400;
#     src: local('Open Sans Regular'), local('OpenSans-Regular'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVZ0bf8pkAg.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFW50d.woff) format('woff');
#     unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOX-hpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOVuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOUehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 600;
#     src: local('Open Sans SemiBold'), local('OpenSans-SemiBold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOUuhpKKSTjw.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UNirkOXOhv.woff) format('woff');
#     unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOX-hpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOVuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXuhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+1F00-1FFF;
# }
# /* greek */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOUehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0370-03FF;
# }
# /* vietnamese */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXehpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0102-0103, U+0110-0111, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhpKKSTj5PW.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#     font-family: 'Open Sans';
#     font-style: normal;
#     font-display: fallback;
#     font-weight: 700;
#     src: local('Open Sans Bold'), local('OpenSans-Bold'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOUuhpKKSTjw.woff2) format('woff2'), url(https://fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN7rgOXOhv.woff) format('woff');
#     unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }</style>
# <style>
#     .org-logo {
#         background-image: url('https://www.udemy.com/staticx/udemy/images/v6/logo-coral.svg');
#     }
#
#     @media (min-resolution: 2dppx),
#     (min-resolution: 192dpi),
#     (-webkit-min-device-pixel-ratio: 2) {
#         @-ms-viewport { width:device-width; zoom:1.0; }
#         .org-logo {
#             /*retina display*/
#             background-image: url('https://www.udemy.com/staticx/udemy/images/v6/logo-coral.svg');
#         }
#     }
# </style>
# <link href="/staticx/udemy/js/webpack/course-landing-page/desktop/hb.c5979ea28eaa779d0c6e.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#     (function () {
#         var head,
#             regExp = "",
#             version = -1,
#             userAgent = navigator.userAgent;
#
#         if (navigator.appName == 'Microsoft Internet Explorer') {
#             regExp = new RegExp("MSIE ([0-9]{1,}[\.0-9]{0,})");
#         } else if (navigator.appName == 'Netscape') {
#             regExp = new RegExp("Trident/.*rv:([0-9]{1,}[\.0-9]{0,})");
#         }
#         if (regExp && regExp.exec(userAgent) != null) {
#             version = parseFloat(RegExp.$1);
#         }
#
#         if (version > 9) {
#             head = document.getElementsByTagName("html")[0];
#             head.className = head.className + " ie";
#             if (version == 10) {
#                 head.className = head.className + " ie10";
#             }
#         }
#     })();
# </script>
# <script>
#     // Polyfill for IE in order to fix errors related with new Event() and new CustomEvent()
#     // https://developer.mozilla.org/en-US/docs/Web/API/CustomEvent/CustomEvent#Polyfill
#     (function () {
#       if ( typeof window.CustomEvent === "function" ) return false;
#       function CustomEvent ( event, params ) {
#         params = params || { bubbles: false, cancelable: false, detail: undefined };
#         var evt = document.createEvent( 'CustomEvent' );
#         evt.initCustomEvent( event, params.bubbles, params.cancelable, params.detail );
#         return evt;
#        }
#       CustomEvent.prototype = window.Event.prototype;
#       window.CustomEvent = CustomEvent;
#       window.Event = CustomEvent;
#     })();
#
#     // Shim for requestIdleCallback.
#     // https://developers.google.com/web/updates/2015/08/using-requestidlecallback
#     window.requestIdleCallback = window.requestIdleCallback || function (cb) {
#       var start = Date.now();
#       return setTimeout(function () {
#         cb({
#           didTimeout: false,
#           timeRemaining: function () {
#             return Math.max(0, 50 - (Date.now() - start));
#           }
#         });
#       }, 1);
#     };
# </script>
# <script>
#     var UD = UD || {};
#     UD.me = {"learning_languages":[],"qualaroo_survey_ids":[],"settings":{},"encrypted_affiliate_email":"","encrypted_affiliate_uid":""};
#     UD.Config = {"app_name":"course_landing_page","features":{"course":{"students":{"unenroll":false},"announcements":{"comments":{"view":true}},"discussions":{"view":true},"refundable":true},"ufb_notices":true,"organization":{"auth":{"custom_error_messaging_enabled":true,"scim_api_enabled":false},"learning_path":{"enabled":false},"enterprise":{"onboarding_enabled":true},"manage_satisfaction":{"satisfaction":false},"manage_insights":{"timeframe_filtering":false}},"ufb_notices_footer":{"top_com":true},"discount":{"change_alerts":true},"bundle":{"instructor_bio":{"social_links":true}},"shopping_cart":true,"hello_bar":{"pricing":true,"terms":true,"instructor":false},"flyout":true,"course_landing_page":{"money_back_guarantee":true,"incentives":{"access_tv":true,"lifetime_access":true},"instructor_bio":{"stats":true,"social_links":true,"image":true}},"social_share":{"welcome_popup":true,"email":true},"course_review":{"clp_review_search":true,"leave_feedback":true},"referral_program_enabled":true,"invite":{"alert":true},"notice":{"smart_bar":true,"instructor_bar":false,"ufb_smart_bar":false},"home":{"signup_cta":true,"my_courses":{"free_label":true,"revenue":true,"privacy":true}},"wishlist":true,"gift_course":true,"zendesk_chat":false,"logged_in_home":{"linkbar_level_2":true,"ufb_ad":false},"intercom_chat":false,"reviews":{"show_user_avatar":true},"report_abuse":true},"third_party":{"google_analytics_id":"UA-12366301-1","stripe_publishable_key":"pk_live_xOuIgZiF7hb3wSwFSAOz3dRm","google_analytics_id_for_ufb_only":"UA-12366301-47","intercom":{"app_id":"sehj53dd"},"filestack":{"video_extensions":[".avi",".mpg",".mpeg",".flv",".mov",".m2v",".m4v",".mp4",".rm",".ram",".vob",".ogv",".webm",".wmv"],"s3_fineuploader_misc_extensions":[".vcf",".chm",".csv",".cml",".spdf",".xmls",".win",".ufd",".csh",".wk3",".png",".fst",".ras",".snd",".kmz",".axv",".stw",".pdf",".odi",".cpkg",".msd",".o",".mrc",".p7c",".asx",".ggb",".sppt",".sm",".mbox",".xlc",".oas",".ahead",".s1h",".msf",".xdw",".dwg",".srx",".u8dsn",".jpm",".jad",".ifb",".tfi",".ic2",".jpx",".vcg",".123",".es3",".iso",".ogg",".pwz",".ic3",".wav",".std",".cww",".uvf",".spl",".omg",".hdr",".bmi",".mseq",".sxw",".m15",".el",".acu",".mwf",".cer",".xpm",".acc",".qwd",".dvi",".azf",".tsa",".s14",".wiz",".mxf",".lwp",".p7s",".msm",".mxu",".lostsyncxml",".ntf",".ogv",".gram",".dd2",".or2",".uvvg",".mods",".scd",".pyc",".f90",".jpgm",".svg",".asf",".vtu",".mpn",".mus",".mc1",".qps",".mtm",".s1g",".c11amz",".study-inter",".xhtm",".rpss",".texi",".rs",".nb",".drc",".5",".7",".rdf-crypt",".iges",".osf",".uri",".ic5",".semd",".tuc",".lasxml",".json-patch",".dvc",".slaz",".webm",".xfdf",".uvi",".potm",".text",".prz",".ic6",".sit",".quox",".mpkg",".gxt",".p8",".oga",".wtb",".xps",".u8msg",".mhtml",".ktx",".provx",".mads",".xmt_bin",".sdp",".cdy",".tlclient",".mmr",".otp",".s3df",".xdp",".wm",".opus",".xpdl",".clkw",".ksh",".ltf",".umj",".mag",".cryptonote",".exi",".ors",".xyz",".sgm",".igl",".docx",".uvp",".kml",".vis",".odc",".hbc",".669",".s11",".vsw",".zaz",".sl",".html",".mft",".c4g",".vsf",".package",".uvv",".koz",".xlam",".xlsx",".smp3",".uvvt",".copyright",".clkx",".odf",".ecelp9600",".shar",".css",".sjp",".m21",".spd",".kne",".cdmid",".mesh",".pptx",".mpg",".rpm",".odg",".dor",".sub",".eol",".tree",".joda",".utz",".smh",".smil",".odb",".ai",".twds",".sc",".kpr",".pyv",".wadl",".ra",".ppm",".oa2",".gac",".zone",".vcd",".xvml",".azv",".odd",".uvz",".gre",".cw",".tcl",".nds",".xml",".vst",".1905.1",".dll",".seml",".igs",".hps",".ftc",".mlp",".smv",".slc",".s1n",".mid",".texinfo",".cuc",".nitf",".mseed",".kwt",".wma",".dpg",".sxls",".djvu",".bin",".uvvd",".smp",".ult",".asc",".qbo",".tpl",".qxd",".btif",".pod",".ief",".sid",".spng",".evw",".ac3",".jnlp",".pls",".iif",".upa",".dm",".hpi",".lmp",".xdf",".rep",".cdmiq",".dpkg",".dr",".sgml",".dart",".evc",".stif",".8",".src",".eot",".jtd",".2",".x_b",".stf",".uvvv",".ssw",".m3u",".tra",".mfm",".dot",".metalink",".wax",".rq",".lostxml",".thmx",".svgz"," ...
#     UD.site_stats = {"default":{"num_topics":2000,"num_instructors":35000,"num_courses":100000,"num_students":24},"organizations":{"num_courses":3500}};
#     UD.visiting = {"visitor_uuid":"c50bdf46aef74cdfa98bd550c5bc4d7b","is_first_time_visitor":true,"first_visit_time":"2019-09-15T08:45:58.190Z"};
#     UD.tracking = {"tracking_enabled":true,"collector_url":"https://event-collector.udsrv.com/api/event","tracking_id":"c6bd45d872c84d70894971cf9f73d6cb"};
# </script>
# <script>
#     UD.request = {
#         locale: 'en_US',
#         third_party_location: '/the-web-developer-bootcamp/',
#         navigation_locale: 'en_US',
#         language_simple_english_title: 'English',
#         termsBarType: '',
#         termsBarUrls: "",
#         isMobile: false,
#         isTablet: false,
#         isPC: true,
#         serverTimestamp: '2019-09-15T08:45:58.459698+00:00',
#         clientTimestamp: new Date().toISOString(),
#
#     };
#     UD.experiment = {"clp":{"2355":{"variant":5981,"state":"recorded","values":{"clp_show_redeem_coupon":true}},"2357":{"variant":5991,"state":"recorded","values":{"learning_packs_variant":"control"}}},"sw":{"2248":{"variant":5670,"state":"recorded","values":{"isCookielessHLS":true}},"2338":{"variant":5938,"state":"recorded","values":{"ufb_header_ad__drop_bell":false,"ufb_header_ad__show_ad":true}},"2334":{"variant":5924,"state":"recorded","values":{"ufb_logged_in_header":"three_rows"}},"2262":{"variant":5710,"state":"recorded","values":{"price_engine_variant":2}}}};
# </script>
# <script>
#     if (window.performance && typeof window.performance.mark === 'function'
#             && typeof window.performance.measure === 'function') {
#         UD.performance = {
#             _trackedResources: [],
#             _eventNamePrefix: 'UD-',
#             trackResourceTiming: function (resourceName, resourceUrl) {
#                 this._trackedResources.push({ name: resourceName, url: resourceUrl });
#             },
#             mark: function (name) {
#                 window.performance.mark(this._eventNamePrefix + name);
#             },
#             start: function (name) {
#                 window.performance.mark(this._eventNamePrefix + '_' + name + '-start');
#             },
#             end: function (name) {
#                 var endMark = this._eventNamePrefix + '_' + name + '-end';
#                 var startMark = this._eventNamePrefix + '_' + name + '-start';
#                 window.performance.mark(endMark);
#
#                 if (window.performance.getEntriesByName(startMark).length > 0) {
#                     window.performance.measure(this._eventNamePrefix + name, startMark, endMark);
#                 }
#             },
#             sync: function() {
#
#                 window.dispatchEvent(new CustomEvent('syncPerf',
#                     { detail: { trackedResources: this._trackedResources } }
#                 ));
#             }
#         };
#     } else {
#         UD.performance = {
#             trackResourceTiming: Function.prototype,
#             mark: Function.prototype,
#             start: Function.prototype,
#             end: Function.prototype,
#             sync: Function.prototype
#         };
#     }
# </script>
# <script>
#             UD.browse = {
#                 navigation_categories: [{"children":[{"children":null,"absolute_url":"/courses/development/web-development/","icon_name":"web-development","id":8,"title_cleaned":"web-development","type":"subcategory","title":"Web Development"},{"children":null,"absolute_url":"/courses/development/mobile-apps/","icon_name":"mobile-apps","id":10,"title_cleaned":"mobile-apps","type":"subcategory","title":"Mobile Apps"},{"children":null,"absolute_url":"/courses/development/programming-languages/","icon_name":"programming-languages","id":12,"title_cleaned":"programming-languages","type":"subcategory","title":"Programming Languages"},{"children":null,"absolute_url":"/courses/development/game-development/","icon_name":"game-development","id":14,"title_cleaned":"game-development","type":"subcategory","title":"Game Development"},{"children":null,"absolute_url":"/courses/development/databases/","icon_name":"databases","id":16,"title_cleaned":"databases","type":"subcategory","title":"Databases"},{"children":null,"absolute_url":"/courses/development/software-testing/","icon_name":"software-testing","id":18,"title_cleaned":"software-testing","type":"subcategory","title":"Software Testing"},{"children":null,"absolute_url":"/courses/development/software-engineering/","icon_name":"software-engineering","id":20,"title_cleaned":"software-engineering","type":"subcategory","title":"Software Engineering"},{"children":null,"absolute_url":"/courses/development/development-tools/","icon_name":"development-tools","id":362,"title_cleaned":"development-tools","type":"subcategory","title":"Development Tools"},{"children":null,"absolute_url":"/courses/development/e-commerce/","icon_name":"e-commerce","id":354,"title_cleaned":"e-commerce","type":"subcategory","title":"E-Commerce"}],"absolute_url":"/courses/development/","icon_name":"development","id":288,"title_cleaned":"development","type":"category","title":"Development"},{"children":[{"children":null,"absolute_url":"/courses/business/finance-courses/","icon_name":"finance","id":24,"title_cleaned":"finance-courses","type":"subcategory","title":"Finance"},{"children":null,"absolute_url":"/courses/business/entrepreneurship/","icon_name":"entrepreneurship","id":26,"title_cleaned":"entrepreneurship","type":"subcategory","title":"Entrepreneurship"},{"children":null,"absolute_url":"/courses/business/communications/","icon_name":"communications","id":28,"title_cleaned":"communications","type":"subcategory","title":"Communications"},{"children":null,"absolute_url":"/courses/business/management/","icon_name":"management","id":30,"title_cleaned":"management","type":"subcategory","title":"Management"},{"children":null,"absolute_url":"/courses/business/sales/","icon_name":"sales","id":32,"title_cleaned":"sales","type":"subcategory","title":"Sales"},{"children":null,"absolute_url":"/courses/business/strategy/","icon_name":"strategy","id":34,"title_cleaned":"strategy","type":"subcategory","title":"Strategy"},{"children":null,"absolute_url":"/courses/business/operations/","icon_name":"operations","id":36,"title_cleaned":"operations","type":"subcategory","title":"Operations"},{"children":null,"absolute_url":"/courses/business/project-management/","icon_name":"project-management","id":38,"title_cleaned":"project-management","type":"subcategory","title":"Project Management"},{"children":null,"absolute_url":"/courses/business/business-law/","icon_name":"business-law","id":40,"title_cleaned":"business-law","type":"subcategory","title":"Business Law"},{"children":null,"absolute_url":"/courses/business/data-and-analytics/","icon_name":"data-and-analytics","id":44,"title_cleaned":"data-and-analytics","type":"subcategory","title":"Data \u0026 Analytics"},{"children":null,"absolute_url":"/courses/business/home-business/","icon_name":"home-business","id":46,"title_cleaned":"home-business","type":"subcategory","title":"Home Business"},{"children":null,"absolute_url":"/courses/business/human-resources/","icon_name":"human-resources ...
#                 popular_subcategory_topics: {"24":[{"absolute_url":"/topic/financial-analysis/","title":"Financial Analysis","id":5800},{"absolute_url":"/topic/investing/","title":"Investing","id":6282},{"absolute_url":"/topic/finance/","title":"Finance Fundamentals","id":5798},{"absolute_url":"/topic/stock-trading/","title":"Stock Trading","id":7900},{"absolute_url":"/topic/financial-modeling/","title":"Financial Modeling","id":5806},{"absolute_url":"/topic/forex/","title":"Forex","id":5868},{"absolute_url":"/topic/excel/","title":"Excel","id":6730},{"absolute_url":"/topic/accounting/","title":"Accounting","id":4328},{"absolute_url":"/topic/python/","title":"Python","id":7380}],"132":[{"absolute_url":"/topic/aws-certification/","title":"AWS Certification","id":4704},{"absolute_url":"/topic/aws-certified-solutions-architect-associate/","title":"AWS Certified Solutions Architect - Associate","id":24774},{"absolute_url":"/topic/cisco-ccna/","title":"Cisco CCNA","id":5044},{"absolute_url":"/topic/comptia-a/","title":"CompTIA A+","id":5166},{"absolute_url":"/topic/aws-certified-developer-associate/","title":"AWS Certified Developer - Associate","id":43860},{"absolute_url":"/topic/comptia-security/","title":"CompTIA Security+","id":5176},{"absolute_url":"/topic/comptia-network/","title":"CompTIA Network+","id":5174},{"absolute_url":"/topic/aws-certified-cloud-practitioner/","title":"AWS Certified Cloud Practitioner","id":46868},{"absolute_url":"/topic/itil-4/","title":"ITIL 4 Foundation","id":107392}],"110":[{"absolute_url":"/topic/photoshop/","title":"Photoshop","id":4402},{"absolute_url":"/topic/graphic-design/","title":"Graphic Design","id":6020},{"absolute_url":"/topic/adobe-illustrator/","title":"Adobe Illustrator","id":4394},{"absolute_url":"/topic/drawing/","title":"Drawing","id":5494},{"absolute_url":"/topic/indesign/","title":"InDesign","id":4396},{"absolute_url":"/topic/digital-painting/","title":"Digital Painting","id":5434},{"absolute_url":"/topic/figure-drawing/","title":"Figure Drawing","id":10470},{"absolute_url":"/topic/logo-design/","title":"Logo Design","id":6570},{"absolute_url":"/topic/coreldraw/","title":"CorelDRAW","id":5244}],"142":[{"absolute_url":"/topic/life-coaching/","title":"Life Coaching","id":10684},{"absolute_url":"/topic/reiki/","title":"Reiki","id":7484},{"absolute_url":"/topic/neuro-linguistic-programming/","title":"Neuro-Linguistic Programming","id":6910},{"absolute_url":"/topic/energy-healing/","title":"Energy Healing","id":5618},{"absolute_url":"/topic/mindfulness/","title":"Mindfulness","id":6770},{"absolute_url":"/topic/neuroscience/","title":"Neuroscience","id":6916},{"absolute_url":"/topic/crystal-energy/","title":"Crystal Energy","id":19020},{"absolute_url":"/topic/emotional-intelligence/","title":"Emotional Intelligence","id":5604},{"absolute_url":"/topic/meditation/","title":"Meditation","id":6680}],"8":[{"absolute_url":"/topic/web-development/","title":"Web Development","id":8322},{"absolute_url":"/topic/javascript/","title":"JavaScript","id":6368},{"absolute_url":"/topic/react/","title":"React","id":7450},{"absolute_url":"/topic/angular/","title":"Angular","id":28016},{"absolute_url":"/topic/css/","title":"CSS","id":5306},{"absolute_url":"/topic/php/","title":"PHP","id":7176},{"absolute_url":"/topic/vue-js/","title":"Vue JS","id":4308},{"absolute_url":"/topic/nodejs/","title":"Node.Js","id":6928},{"absolute_url":"/topic/django/","title":"Django","id":5464}],"10":[{"absolute_url":"/topic/android-development/","title":"Android Development","id":4470},{"absolute_url":"/topic/ios-development/","title":"iOS Development","id":6292},{"absolute_url":"/topic/google-flutter/","title":"Google Flutter","id":52458},{"absolute_url":"/topic/swift/","title":"Swift","id":7956},{"absolute_url":"/topic/react-native/","title":"React Native","id":9884},{"absolute_url":"/topic/dart-programming-language/","title":"Dart Programming Language","id":37860},{"absolute_url":"/topic/mobile-development/","title":"Mo ...
#             };
#         </script>
# <script>
#
#     window.GoogleAnalyticsObject = 'ga';
#     window.ga = function () {
#         (window.ga.q = window.ga.q || []).push(arguments);
#     };
#     window.ga.l = 1 * new Date();
#
#     UD.GoogleAnalytics = UD.GoogleAnalytics || {};
#     UD.GoogleAnalytics.createAccount = function (accountId, propertyName, domainName) {
#         if (accountId) {
#             if (propertyName) {
#                 // Required for multiple trackers
#                 window.ga('create', accountId, 'auto', {'name': propertyName, 'cookieDomain': domainName || 'none',
#                     'siteSpeedSampleRate': 10});
#             } else {
#                 window.ga('create', accountId, 'auto', {'siteSpeedSampleRate': 10});
#                 window.ga('require', 'displayfeatures'); // Enables retargeting
#             }
#             window.ga('set', {
#                 'anonymizeIp': true,
#                 'location' : ""
#             });
#         }
#     };
#     UD.GoogleAnalytics.createAccount(UD.Config.third_party.google_analytics_id);
# </script>
# <script>
#    (function activateMyQualaroos(surveyIds) {
#         window._kiq = window._kiq || [];
#         var i, property;
#         for (i = 0; i < surveyIds.length; i++) {
#             property = {};
#             property[surveyIds[i]] = true;
#             window._kiq.push(['set', property]);
#         }
#         window._kiq.push(['identify', UD.visiting.visitor_uuid || '']);
#     })(UD.me.qualaroo_survey_ids);
# </script>
# <script>
#     window.hj=window.hj||function(){(hj.q=hj.q||[]).push(arguments)};
# </script>
# <script src="https://cdn.optimizely.com/js/305025425.js" type="text/javascript"></script>
# <base href="/the-web-developer-bootcamp/"/>
# <link href="https://www.udemy.com/the-web-developer-bootcamp/" rel="canonical"/>
# </head>
# <body class=" landing-page ud-app-loader udemy " data-clp-course-id="625204" data-hotjar-bw="hb" data-hotjar-device="desktop" data-hotjar-page="clp" data-module-args='{"rating":4.64289,"sourcePage":"clp","title":"The Web Developer Bootcamp","datadogTags":{"frame":"visitor","root":"course_landing_page/frames/desktop/hb","localized":false},"initial_components":["buy_button","discount_expiration","gift_this_course","introduction_asset","purchase","deal_badge","redeem_coupon"],"subcategoryId":8,"url":"/the-web-developer-bootcamp/","is_private":false,"grouped_components":[["curriculum","practice_test_bundle","instructor_bio","topic_menu"]],"is_wishlisted":false,"is_paid":true,"isFreeSEOExp":false,"vectors":{"device":"desktop","bandwidth":"hb"},"course_id":625204,"is_published":true}' data-module-id="course-landing-components" id="udemy">
# <div class="main-content-wrapper">
# <div class="ud-app-loader ud-component--smart-bar--app" data-module-id="smart-bar" data-module-priority="-10"></div>
# <div class="c_header c_header--v6 c_header--desktop c_header--ia c_header--ia- ud-app-loader " data-module-args='{"mobileNav":{"support":{"url":"/support/"},"browse":{"text":"Categories"},"mobileApp":{"url":"https://udemy.app.link/garBkjjtDO"},"performanceEnabled":false,"ufb":{"text":"Udemy for Business","url":"https://business.udemy.com/request-demo/?locale=en_US\u0026ref=ufb_header"},"teachHub":{"url":"https://teach.udemy.com/home"},"instructor":{"text":"Teach on Udemy","url":"/teaching/?ref=teach_header","trackingDetail":"become-an-instructor"}},"manageUFBDropdownButton":{"badges":{}},"wishlistDropdown":{"listName":"wishlist"},"cartDropdown":{"listName":"cart"},"creditMessage":null,"app":{"isStudent":false,"navUserType":null,"features":{"payout_settings":false,"revenue_report":false,"exp_try_ufb":"control","profile":true,"notifications":true,"messaging":true,"signup":true,"invite":true,"show_ufb_link":true,"wishlist":true,"instructor_signup_modal":false,"payments":true,"browse":true,"discussions":true,"public_profile":true,"language_select":false,"teaching":true,"reviews":true,"ufb_ad_logged_in_header":false,"teach_link":true},"user":null,"isMobile":false,"isUFB":false,"isInstructor":false,"isLearningPathEnabled":false}}' data-module-id="header-v6" data-module-priority="-10">
# <div aria-label="Main navigation" class="c_header__inner" role="navigation">
# <div class="c_header__logo-container">
# <a class="js-tracked-without-react c_header__logo-wrap" data-tracking-event="logo" href="/" target="_self">
# <img alt="Udemy" class="udemy-logo" data-purpose="udemy-brand-logo" height="32" src="https://www.udemy.com/staticx/udemy/images/v6/logo-coral.svg" width="110"/>
# </a>
# </div>
# <div class="c_header__left">
# <div class="ud-component--header-v6--mobile-nav-trigger">
# <button aria-label="Menu" class="btn btn-link c_header__mobile-bt" data-purpose="side-menu-opener">
# <span class="udi udi-menu"></span>
# </button>
# </div>
# <div class="ud-component--header-v6--browse-dropdown-button hidden-xs hidden-xxs">
# <div class="dropdown dropdown--open-on-hover dropdown--topics">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-purpose="browse-courses-link" href="javascript:void(0)" id="header.browse" role="button">
# <span class="udi udi-explore"></span>
# <span>Categories</span>
# </a>
# <ul aria-labelledby="header.browse" class="dropdown-menu" role="menu">
# <li class="h100p" id="header.browse.categories">
# <ul class="dropdown-menu__list dropdown-menu__list--level-one">
# <li class="menu__placeholder" id="header.browse.placeholder.94">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 94px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.61">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 61px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.93">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 93px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.128">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 128px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.159">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 159px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.47">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 47px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.70">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 70px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.57">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 57px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.90">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 90px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.113">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 113px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.116">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 116px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.40">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 40px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.74">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 74px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.67">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 67px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# <li class="menu__placeholder" id="header.browse.placeholder.65">
# <div class="menu__placeholder--icon"></div>
# <div class="menu__placeholder--text-wrapper">
# <div class="menu__placeholder--text" style="width: 65px"></div>
# </div>
# <span class="udi udi-next menu__arrow"></span>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="c_header__search-wrapper ud-component--header-v6--header-es-autocomplete">
# <div class="c_header__search">
# <button aria-label="Search" class="btn btn-link c_header__mobile-bt">
# <span class="udi udi-search"></span>
# </button>
# <div class="c_quick-search__form">
# <form action="/courses/search/" class="es-autocomplete es-autocomplete--primary">
# <input name="src" type="hidden" value="ukw"/>
# <label class="sr-only" for="header-search-field">
# Search for anything
# </label>
# <div class="input-group">
# <input autocomplete="off" class="form-control" data-purpose="search-input" id="header-search-field" maxlength="200" name="q" placeholder="Search for anything" type="text" value=""/>
# <span class="input-group-btn">
# <button aria-label="Search" class="btn btn-link" type="submit">
# <span class="udi udi-search"></span>
# </button>
# </span>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="c_header__mobile-spacer"> </div>
# <div class="c_header__right">
# <div class="ud-component--header-v6--try-ufb-dropdown-button visible-lg-block visible-xl-block">
# <div class="dropdown dropdown--ufb zero-state">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle dropdown__toggle dropdown__main-link" data-allow-referrer="" data-purpose="ufb-link" data-tracking-event="ufb.main" href="https://business.udemy.com/request-demo/?locale=en_US&amp;ref=ufb_header" id="header.try-ufb" rel="noopener" role="button" target="_blank">
# Udemy for Business
# </a>
# </div>
# <ul aria-labelledby="header.try-ufb" class="dropdown-menu dropdown-menu-right" role="menu">
# <li id="header.try-ufb.detail">
# <div class="zero-state__detail">
# Get your team access to 3,500+ top Udemy courses anytime, anywhere
# </div>
# <div class="mt-space-sm">
# ...
#             </p>
#             <div class="audience" data-purpose="course-audience">
#              <div class="audience__title">
#               Who this course is for:
#              </div>
#              <ul class="audience__list">
#               <li>
#                This course is for anyone who wants to learn about web development, regardless of previous experience
#               </li>
#               <li>
#                It's perfect for complete beginners with zero experience
#               </li>
#               <li>
#                It's also great for anyone who does have some experience in a few of the technologies(like HTML and CSS) but not all
#               </li>
#               <li>
#                If you want to take ONE COURSE to learn everything you need to know about web development, take this course
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="featured-review ">
#          <div class="featured-review__title " data-purpose="featured-review-title">
#           Featured review
#          </div>
#          <div class="featured-review__container ">
#           <div class="featured-review__row-1">
#            <div data-purpose="featured-review-avatar">
#             <img alt="Christan Price" aria-label="Christan Price" class="user-avatar user-avatar--image " data-purpose="user-avatar" height="48" src="https://i.udemycdn.com/user/50x50/702178_2b8d_2.jpg" width="48"/>
#            </div>
#            <div class="featured-review__reviewer">
#             <span class="featured-review__user-title" data-purpose="featured-review-user-title">
#              Christan Price
#             </span>
#             (
# 20 courses,
# 2 reviews
# )
#             <div class="feature-review__rating">
#              <span class="star-rating--static star-rating--smaller">
#               <span style="width: 100%">
#               </span>
#              </span>
#             </div>
#             <div data-purpose="featured-review-created">
#              3 months ago
#             </div>
#            </div>
#           </div>
#           <div class="ud-component--clp--featured-review-content" data-component-args="{&quot;reviewId&quot;:32169550,&quot;reviewContent&quot;:&quot;Im about 2 days from finishing and having an app deployed on Heroku that has user authentication that I can access from my phone is really cool. Colt is a great instructor and I've learned a lot! My only advice is don't forget that you're doing this for your self so take your time and build your own projects after you finish an assignment so you can \&quot;really\&quot; get it. Already recommended this course to a friend who's taking it now.&quot;,&quot;courseId&quot;:625204}">
#            Im about 2 days from finishing and having an app deployed on Heroku that has user authentication that I can access from my phone is really cool. Colt is a great instructor and I've learned a lot! My only advice is don't forget that you're doing this for your self so take your time and build your own projects after you finish an assignment so you can "really" get it. Already recommended this course to a friend who's taking it now.
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="recommendations" data-purpose="recommendations-unit">
#          <span class="in-page-offset-anchor" data-purpose="recommendations-offset-anchor">
#          </span>
#          <div class="recommendations__course-cards ud-app-loader ud-component--course-comparison--app" data-module-args='{"funnelTrackingContext":"landing-page","funnelTrackingSubcontext":"best-seller","funnelTrackingSubcontext2":"view-coursecomparison","currentCourseId":625204,"discoveryContext":"landing-page","sourcePage":"course_landing_page"}' data-module-id="course-comparison">
#           <div class="recommendations__content recommendations__content--course-comparison">
#            <div class="recommendations__title">
#             <div class="content-loader__cc-content">
#             </div>
#            </div>
#            <ul class="content-loader--list">
#             <li class="content-loader__cc-row">
#              <span class="content-loader__cc-image">
#               <div class="content-loader__cc-content content-loader__cc-content--full-height">
#               </div>
#              </span>
#              <span class="content-loader__cc-text">
#               <div class="content-loader__cc-content">
#               </div>
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#             </li>
#             <li class="content-loader__cc-row">
#              <span class="content-loader__cc-image">
#               <div class="content-loader__cc-content content-loader__cc-content--full-height">
#               </div>
#              </span>
#              <span class="content-loader__cc-text">
#               <div class="content-loader__cc-content">
#               </div>
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#             </li>
#             <li class="content-loader__cc-row">
#              <span class="content-loader__cc-image">
#               <div class="content-loader__cc-content content-loader__cc-content--full-height">
#               </div>
#              </span>
#              <span class="content-loader__cc-text">
#               <div class="content-loader__cc-content">
#               </div>
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#              <span class="content-loader__cc-stats">
#               <div class="content-loader__cc-content">
#               </div>
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="ud-component--clp--bundle" data-component-args="{}">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="ud-component--clp--practice-test-bundle" data-component-args="{}">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="instructor ">
#          <span class="in-page-offset-anchor" id="instructor">
#          </span>
#          <div class="ud-component--clp--instructors">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8 left-col">
#        <div class="clp-component-render">
#         <div class="" data-purpose="course-reviews">
#          <span class="in-page-offset-anchor" id="reviews">
#          </span>
#          <div class="ud-component--clp--course-reviews-display" data-component-args='{"courseId":625204,"averageRating":4.64289,"topReviewAttributes":[],"ratingDistribution":[{"rating":1,"count":376},{"rating":2,"count":842},{"rating":3,"count":6612},{"rating":4,"count":36162},{"rating":5,"count":91700}],"isFreeSEOExp":false,"showUserAvatar":true,"page":"clp"}'>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8">
#        <div class="clp-component-render">
#         <div class="more-from-instructor ud-component--clp--more-courses-by-instructors" data-component-args='{"data":{"context":"landing-page","instructors":[{"id":4466306,"title":"Colt Steele"}],"courseIsPaid":true,"subContext":"morefrominstructor","organizationCoursesOnly":false,"courseId":625204}}'>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row">
#       <div class="col-xxs-8">
#        <div class="clp-component-render">
#         <div class="ud-component--clp--price-disclaimer" data-component-args="{}">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="row">
#       <div class="col-xxs-8">
#       </div>
#      </div>
#      <div class="row row--component-margin">
#       <div class="col-xxs-8">
#        <div class="clp-component-render">
#         <div class="ud-component--clp--report-abuse report-abuse" data-purpose="report-abuse-link">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-v6 footer--marketplace ud-app-loader ud-component--footer--app footer--en-us " data-module-args='{"localeDropdown":{"currentLanguage":"English"},"ufbNotice":{"link":"https://business.udemy.com/request-demo/?locale=en_US\u0026ref=footer-ad"},"mobileAppDownload":{"link":"https://udemy.app.link/garBkjjtDO"}}' data-module-id="footer" data-module-priority="-20" data-purpose="footer-bar">
#     <div class="fixed-message-container">
#      <div class="ud-component--footer--legal-message">
#      </div>
#      <div class="ud-app-loader ud-component--footer--eu-cookie-message" data-module-id="eu-cookie-message" data-module-priority="-20">
#      </div>
#     </div>
#     <footer>
#      <hr/>
#      <div class="container-fluid footer__main">
#       <div class="row">
#        <div class="hidden-xxs hidden-xs col-sm-9 footer__links--main">
#         <ul class="links ">
#          <li>
#           <a class="ud-click-tracking bold" data-purpose="footer.links.business" data-type="udemy-business-footer-clicked" href="https://business.udemy.com/?locale=en_US&amp;ref=footer">
#            Udemy for Business
#           </a>
#          </li>
#          <li>
#           <a class=" bold" data-purpose="footer.links.teach" href="/teaching/?ref=teach_footer">
#            Teach on Udemy
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.mobile" href="/mobile/">
#            Udemy app
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.about" href="https://about.udemy.com/?locale=en-us">
#            About us
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.careers" href="https://about.udemy.com/careers?locale=en-us">
#            Careers
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.blog" href="https://about.udemy.com/blog?ref=footer">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.support" href="/support/">
#            Help and Support
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.affiliates" href="/affiliate/" title="Udemy Affiliate Program">
#            Affiliate
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.sitemap" href="/sitemap/">
#            Sitemap
#           </a>
#          </li>
#          <li>
#           <a class=" " data-purpose="footer.links.popular_courses" href="/popular-courses/">
#            Popular courses
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="col-sm-3">
#         <div class="ud-component--footer--locale-dropdown text-right footer__locale-dropdown">
#          <div class="dropup btn-group locale-dropdown">
#           <button aria-expanded="false" aria-haspopup="true" aria-label="Select language" class="dropdown-toggle btn btn-sm btn-quaternary" data-purpose="locale-dropdown-btn" id="locale-dropdown" role="button" type="button">
#            <span>
#             <span class="mr15">
#              <span class="ml10 mr10 udi udi-globe">
#              </span>
#              <span class="mr10">
#               English
#              </span>
#             </span>
#             <span class="pos-a" style="right: 12px;">
#              <span class="dropdown-caret udi udi-angle-down">
#              </span>
#             </span>
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <hr/>
#      <div class="ud-component--footer--ufb-notice">
#      </div>
#      <hr/>
#      <div class="container-fluid footer__bottom">
#       <div class="row">
#        <div class="col-sm-6">
#         <a class="dib mr20" href="/">
#          <img alt="Udemy" class="ufb-logo" height="32" src="https://www.udemy.com/staticx/udemy/images/v6/logo-coral.svg" width="110"/>
#         </a>
#         <div class="visible-xxs-block visible-xs-inline-block mb10">
#         </div>
#         <span class="footer__copyright dib mr20 text-midnight-lighter">
#          Copyright © 2019 Udemy, Inc.
#         </span>
#         <div class="visible-xxs-block visible-xs-inline-block mb10">
#         </div>
#        </div>
#        <div class="col-sm-6 text-right footer__links--bottom">
#         <ul class="links list-inline">
#          <li>
#           <a data-purpose="terms-link" href="/terms/">
#            Terms
#           </a>
#          </li>
#          <li>
#           <a data-purpose="privacy-link" href="/terms/privacy/">
#            Privacy Policy and Cookie Policy
#           </a>
#          </li>
#          <li class="footer__sitemap">
#           <a class=" " data-purpose="footer.links.sitemap" href="/sitemap/">
#            Sitemap
#           </a>
#          </li>
#          <li class="footer__sitemap">
#           <a class=" " data-purpose="footer.links.popular_courses" href="/popular-courses/">
#            Popular courses
#           </a>
#          </li>
#          <li class="footer__app-download-link ud-component--footer--mobile-app-download-link">
#           <a data-purpose="app-download-link" href="https://udemy.app.link/garBkjjtDO" target="_blank">
#            Get the app
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <hr class="hr-primary"/>
#      <div class="ud-component--footer--incentive-signup">
#      </div>
#      <div class="ud-component--footer--share-welcome-popup">
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script defer="" src="/staticx/udemy/js/webpack/entry-manifest.dbfc2183402f8d2ab8b3.js" type="text/javascript">
#   </script>
#   <script defer="" src="/staticx/udemy/js/webpack/entry-main-legacy-vendor.71d2ad9f8555ad6ff812.js" type="text/javascript">
#   </script>
#   <script defer="" src="/staticx/udemy/js/webpack/jsi18n-en-us.6bac883c475211481ec4.js" type="text/javascript">
#   </script>
#   <script defer="" src="/staticx/udemy/js/webpack/entry-main-legacy.e3fc55729a77e2478260.js" type="text/javascript">
#   </script>
#   <div class="ud-app-loader ud-component--event-tracking--tracker-initializer" data-module-id="event-tracking" data-module-priority="-10">
#   </div>
#  </body>
# </html>
